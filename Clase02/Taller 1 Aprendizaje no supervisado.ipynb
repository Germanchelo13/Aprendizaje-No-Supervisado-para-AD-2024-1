# %% [markdown]
# # Taller 1
#
# Fecha de entrega: hasta las 12:00 pm del Miercoles 31 de enero del 2024.
#
#
# Cada uno de los siguientes puntos, tiene un chunck destinado para cada punto. Cada punto (excepto el punto 5) debe estar en una variable punto_"núemro del punto", por ejemplo: punto_1, punto_2, ... , etc.
#
# 1. Crea una lista con 3 elementos, cada elemento debe contener una lista de 3 números de 7 digitos.
#
# 2. Crea una lista con 4 elementos, donde cada elemento debe tener una lista con: Edad, nombre y Género en formato booleano (True: Masculino, False: Femenino).
#
# 3. Realice una lista con la lista 1 y 2.
#
# 4. Una los elementos de las listas del punto 1 y 2.
#
# 5. Imprima la longitud de la lista para los puntos 3 y 4.
#
# 6. Crea una lista que contenga 4 elementos, dichos elementos que sean programas de pregrado.
#
# 7. Crea un diccionario que tenga las listas de los puntos 1, 2 y 6, con la llave "Ingresos" para el punto 1, con la llave "Estudiantes" para el punto 2 y con la llave "Programas" para el punto 6.
#
# 8. Crea una matriz utilizando el elemento del diccionario que tiene como llave "Ingresos".
#
# 9. Crea un Data Frame utilizando los elementos del diccionario que tienen como llaves  "Estudiantes" y "Programas", también que contenga nombres en las columnas ("Edad", "Nombre", "Género").
#
# 10.  Con el Data Frame del punto nueve, selecciona las columnas Edad y Género, obtenga el promedio de cada columna.

# %%
# Librerías para el desarrollo del taller
import pandas as pd
import numpy as np

# %%
# Punto 1
punto_1 =

# %%
# Punto 2
punto_2 =

# %%
# Punto 3
punto_3 =

# %%
# Punto 4
punto_4 =

# %%
# Punto 5

# %% [markdown]
# Resultado esperado del punto 5:
# ```
# 2
# 7
# ```

# %%
# Punto 6
punto_6 =

# %%
# Punto 7
punto_7=

# %% [markdown]
# Para la siguiente línea de código se espera como resultado
#
# ```python
# puntos_7.keys()
#  ```
# ``
# dict_keys(['Ingresos', 'Estudiantes', 'Programas'])
# ``

# %%
list(punto_7.keys())

# %%
# Punto 8
punto_8=

# %%
# Punto 9
punto_9=

# %%
# Punto 10
punto_10 =

# %% [markdown]
# Resultado de los ítems:
#
# Al ejecutar todos los chunck, no debe existir ningún error en la ejecución.

# %%
print( punto_1)
print( punto_2)
print( punto_3)
print( punto_4)
print( punto_6)
print( punto_7)
print( punto_8)
print( punto_9)
print( punto_10)
